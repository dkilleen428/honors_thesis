# %%
import numpy as np
import pandas as pd
import sklearn.linear_model as lm
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import Markdown

import scipy.stats

import warnings
warnings.filterwarnings("ignore")

# %%
 pip install openpyxl

# %%
# Read the Excel file into a DataFrame
verra_df = pd.read_excel("data/Verra VCUS.xlsx")
verra_df.head()
# Out:
#   Issuance Date Sustainable Development Goals Vintage Start Vintage End    ID  \
# 0    2024-02-20                           NaN    2022-12-01  2022-12-31  2309
# 1    2024-02-20                           NaN    2023-01-01  2023-05-31  2309
# 2    2024-02-19                           NaN    2013-01-01  2013-12-31  1122
# 3    2024-02-19                           NaN    2022-01-01  2022-12-31  1812
# 4    2024-02-19                           NaN    2023-01-01  2023-08-31  1856
#
#                                                 Name      Country/Area  \
# 0                         Henrietta solar PV project         Mauritius
# 1                         Henrietta solar PV project         Mauritius
# 2                         April Salumei REDD Project  Papua New Guinea
# 3                              VTRM Renewable Energy            Brazil
# 4  Bundled Wind Power Project by Sembcorp Green I...             India
#
# ...

# %%
verra_df['Retirement Details'].value_counts()
# Out:
# Retirement Details
# Private offset                                              22242
# Environmental Benefit                                        1518
# Carbon Neutral by Carbonext                                  1402
# Toucan                                                        861
# Offset Personal Carbon Footprint                              610
#                                                             ...
# retiring DYVIN3T4WBW0PI0: 1 at 2019-09-18T03:48:30.237Z         1
# retiring 3D2CL60RSUBWYI0: 1 at 2019-09-18T12:58:06.229Z         1
# retiring EDYENHE2GERVII0: 10 at 2019-09-18T13:07:17.333Z        1
# retiring AH7IQ4IAERPPFI2: 4 at 2019-09-19T12:18:49.545Z         1
# Offset on Behalf of Impact Hub S.L.U.                           1
# Name: count, Length: 82551, dtype: int64

# %%
pattern = r'TOUCAN.\S*'
replacement = 'Toucan' 

verra_df['Retirement Details'] = verra_df['Retirement Details'].str.replace(pattern, replacement, regex=True)

# %%
verra_df['is Toucan'] = verra_df['Retirement Details'].str.contains('Toucan')
verra_df.head()
# Out:
#   Issuance Date Sustainable Development Goals Vintage Start Vintage End    ID  \
# 0    2024-02-20                           NaN    2022-12-01  2022-12-31  2309
# 1    2024-02-20                           NaN    2023-01-01  2023-05-31  2309
# 2    2024-02-19                           NaN    2013-01-01  2013-12-31  1122
# 3    2024-02-19                           NaN    2022-01-01  2022-12-31  1812
# 4    2024-02-19                           NaN    2023-01-01  2023-08-31  1856
#
#                                                 Name      Country/Area  \
# 0                         Henrietta solar PV project         Mauritius
# 1                         Henrietta solar PV project         Mauritius
# 2                         April Salumei REDD Project  Papua New Guinea
# 3                              VTRM Renewable Energy            Brazil
# 4  Bundled Wind Power Project by Sembcorp Green I...             India
#
# ...

# %%
verra_df['is Toucan'].value_counts()
# Out:
# is Toucan
# False    151392
# True        871
# Name: count, dtype: int64

# %%
verra_df.columns
# Out:
# Index(['Issuance Date', 'Sustainable Development Goals', 'Vintage Start',
#        'Vintage End', 'ID', 'Name', 'Country/Area', 'Project Type',
#        'Methodology', 'Total Vintage Quantity', 'Quantity Issued',
#        'Serial Number', 'Additional Certifications',
#        'Retirement/Cancellation Date', 'Retirement Beneficiary',
#        'Retirement Reason', 'Retirement Details', 'is Toucan'],
#       dtype='object')

# %%
verra_df.to_csv('data/verra.csv', index=False)
